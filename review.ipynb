# %%
import pandas as pd

df = pd.read_csv('listings.csv')
df_callendar = pd.read_csv('calendar.csv')

# %%
def remove_dollar_sign(price:str):
    return price.replace('$','').replace(',','')
df['price'] =  df['price'].apply(remove_dollar_sign).astype('float32')

# %%
df_callendar.head(2)
# Out:
#    listing_id        date available       price adjusted_price  \
# 0     5198467  2022-09-23         t  $16,881.00     $16,881.00
# 1     5198467  2022-09-24         t  $16,881.00     $16,881.00
#
#    minimum_nights  maximum_nights
# 0               3            1125
# 1               3            1125

# %%
df_callendar[df_callendar['listing_id'] == 50380624]
# Out:
#          listing_id        date available        price adjusted_price  \
# 2394400    50380624  2022-09-23         t  $999,999.00    $999,999.00
# 2394401    50380624  2022-09-24         t  $999,999.00    $999,999.00
# 2394402    50380624  2022-09-25         t  $999,999.00    $999,999.00
# 2394403    50380624  2022-09-26         t  $999,999.00    $999,999.00
# 2394404    50380624  2022-09-27         t  $999,999.00    $999,999.00
# ...             ...         ...       ...          ...            ...
# 2394760    50380624  2023-09-18         t  $999,999.00    $999,999.00
# 2394761    50380624  2023-09-19         t  $999,999.00    $999,999.00
# 2394762    50380624  2023-09-20         t  $999,999.00    $999,999.00
# 2394763    50380624  2023-09-21         t  $999,999.00    $999,999.00
# 2394764    50380624  2023-09-22         t  $999,999.00    $999,999.00
#
#          minimum_nights  maximum_nights
# 2394400               1             365
# 2394401               1             365
# ...

# %%
df['availability_365'].unique()
# Out:
# True

# %%
#df_uses =  df[df['availability_30'] != 30]

# %%
df[df['price']>300000]
# Out:
#                       id                                      listing_url  \
# 1129            23227269            https://www.airbnb.com/rooms/23227269
# 1313            24844134            https://www.airbnb.com/rooms/24844134
# 2763            32851119            https://www.airbnb.com/rooms/32851119
# 2931            33454125            https://www.airbnb.com/rooms/33454125
# 3116            34372125            https://www.airbnb.com/rooms/34372125
# 3996            38367996            https://www.airbnb.com/rooms/38367996
# 4362            39422363            https://www.airbnb.com/rooms/39422363
# 4852            40953417            https://www.airbnb.com/rooms/40953417
# 5232            41887514            https://www.airbnb.com/rooms/41887514
# 5234            41887793            https://www.airbnb.com/rooms/41887793
# 5364            42233219            https://www.airbnb.com/rooms/42233219
# 5365            42233313            https://www.airbnb.com/rooms/42233313
# ...

# %%
#df[(df['price']< 20000) & (df['beds'] > 5)]

# %%
df[df['price'] > 600000]
# Out:
#                       id                                      listing_url  \
# 1129            23227269            https://www.airbnb.com/rooms/23227269
# 1313            24844134            https://www.airbnb.com/rooms/24844134
# 2763            32851119            https://www.airbnb.com/rooms/32851119
# 2931            33454125            https://www.airbnb.com/rooms/33454125
# 4852            40953417            https://www.airbnb.com/rooms/40953417
# 5232            41887514            https://www.airbnb.com/rooms/41887514
# 5234            41887793            https://www.airbnb.com/rooms/41887793
# 5364            42233219            https://www.airbnb.com/rooms/42233219
# 5365            42233313            https://www.airbnb.com/rooms/42233313
# 7449            49163406            https://www.airbnb.com/rooms/49163406
# 7714            50380624            https://www.airbnb.com/rooms/50380624
# 9346  658187364482654097  https://www.airbnb.com/rooms/658187364482654097
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df["price"].quantile(0.999)
# Out:
# 337700.00000004075
